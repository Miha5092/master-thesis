# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Imports & Functions

# %%
import numpy as np

from src.utils.visualization import plot_experiments, plot_error_distributions

# %%
# random_experiments_names = [
#     "ViT - random placement",
#     "VCNN UNet - random placement",
#     "VCNN classic - random placement",
# ]

# random_experiments_results = [
#     np.load('results/predictions/vitae/model_random_unet-tiny_random (30)_min-max_predictions.npz'),
#     np.load('results/predictions/vcnn/model_random_tiny_random (30)_min-max_predictions.npz'),
#     np.load('results/predictions/vcnn/model_random_classic_random (30)_min-max_predictions.npz'),
# ]

t4_experiments_names = [
    "ViT - 4 real timesteps",
    "VCNN UNet - 4 real timesteps",
    "VCNN classic - 4 real timesteps",
]

t4_experiments_results = [
    np.load('results/predictions/vitae/t4_unet_real_predictions.npz'),
    np.load('results/predictions/vcnn/t4_tiny_real_predictions.npz'),
    np.load('results/predictions/vcnn/t4_classic_real_predictions.npz'),
]

# %% [markdown]
# # Current model performance

# %%
plot_experiments(random_experiments_names, random_experiments_results)

# %%
plot_experiments(t4_experiments_names, t4_experiments_results)

# %%
plot_error_distributions(random_experiments_names, random_experiments_results)

# %%
plot_error_distributions(t4_experiments_names, t4_experiments_results)
